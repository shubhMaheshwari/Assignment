% %% [markdown]
% # Applying and implementing convolution

% %%
img = imread('./cameraman.png');
imshow(img)
size(img);

% %%
M = [1 2 1; 0 0 0; -1 -2 -1];
M = double(M);

% %%
new_img = conv2(M,img);
new_img = mat2gr
imshow(new_img)

% %%
new_image = conv2(M',img');
imshow(new_img)
