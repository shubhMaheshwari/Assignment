% %% [markdown]
% # 2D FFT

% %% [markdown]
% ### 1D FFT

% %% [markdown]
% ### Test our function on multiple images

% %%
img = imread('./cameraman.png');
imshow(img);
img = double(img);

% %%
temp_1 = zeros(size(img));
temp_2 = temp_1;
col = size(img,2)
row = size(img,1);

for i = 1:row
    temp_2(i,:) = fft_temp(temp_1(i,:).');
end

for i = 1:col
    temp_1(:,i) = fft_temp(inp(:,i));
end    
output = temp_2;
% Out:
% col =
%
%    256
% Error using eval
% Undefined function 'fft_temp' for input arguments of type 'double'.

% %%
img = imread('./blur.jpg');
img = rgb2gray(img);
img = imresize(img,1/3);
imshow(img);
img = double(img);

% %%
new_img = NEW_FFT2(img);

% %%
img = imread('./Faces.jpg');
img = rgb2gray(img);
img = imresize(img,1/4);
imshow(img);
img = double(img);

% %%
new_img = NEW_FFT2(img);
