# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Statistical Signal Processing

# %% [markdown]
# ## Polynomial Regression
# ## Multidimension Signals as Inputs

# %% [markdown]
# ![image.png](attachment:image.png)
