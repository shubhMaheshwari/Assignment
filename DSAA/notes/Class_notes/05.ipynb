# %% [markdown]
# # 2D covlolution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Size of the final outcome depends on both signals

# %% [markdown]
# Averaging filter causes bluring at by averaging the edges
#
#
#       1 1 1
#       1 1 1
#       1 1 1

# %% [markdown]
# But this is not a prefect blurring filter at it averages over a large values if filter size if big

# %% [markdown]
# Hence we use a gaussian filter

# %% [markdown]
# ## Moving average
# https://www.google.co.in/url?sa=t&rct=j&q=&esrc=s&source=web&cd=5&ved=0ahUKEwjngPfEjtzYAhXLybwKHanfBl0QFghBMAQ&url=https%3A%2F%2Fen.wikipedia.org%2Fwiki%2FMoving_average&usg=AOvVaw3Vfh2JEc4LxsHhTwtTpqxW
#
# as a convolution
#
#
# y(n) = 1/N * Sum(x(n-m))

# %% [markdown]
# ### Center limint theoram
# https://en.wikipedia.org/wiki/Central_limit_theorem

# %% [markdown]
# ## Gaussian Distribuiton for simulation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We use this before Edge detection.
# Because the filter of edge detection is highly sensitive to noise
#
#
# Hence we get filter as for div = 1 and mean =0 for 2D
#
#     e-2  e-1/2 e-2
#     e-1/2  1   e-1/2
#     e-2  e-1/2 e-2

# %% [markdown]
# ## Gothe's Temperature measurement

# %% [markdown]
# https://www.coursera.org/learn/dsp

# %% [markdown]
# y(n) = 1/N * Sum(x(n-m))

# %% [markdown]
# - Spike Detection
# - Low Pass component => Averaging filter
# - High Pass component => Subtract averaging filter from og signal
# - If L is small more suspectable to noise
# - If L is small can't detect spike properly

# %% [markdown]
# #### Recursive moving average
#
# y[n] = [x(n) - x(n-N)]/N + y(n-1)
